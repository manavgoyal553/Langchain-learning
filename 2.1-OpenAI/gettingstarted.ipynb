# %% [markdown]
# ## Getting started with Langchain and OPENAI

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GROQ_API_KEY']=os.getenv("GROQ_API_KEY")
os.environ['LANGCHAIN_API_KEY']=os.getenv("LANGCHAIN_API_KEY")
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
## Input and get response from LLM
llm.invoke("What is generative AI")
# Out:
# AIMessage(content='Generative AI refers to a subfield of artificial intelligence (AI) that focuses on the development of algorithms, models, and systems capable of generating new, original, and often creative content. This can include text, images, music, videos, and even entire worlds or scenarios.\n\nGenerative AI models are trained on large datasets and use complex mathematical techniques, such as neural networks, to learn patterns, relationships, and structures within the data. They can then use this knowledge to generate new content that is similar in style, tone, or quality to the original data.\n\nThere are several types of generative AI models, including:\n\n1. **Text Generators**: These models can generate text based on a prompt, topic, or style. They can be used to create articles, stories, dialogue, or even entire scripts.\n2. **Image Generators**: These models can generate images, such as faces, landscapes, or objects. They can be used to create art, graphics, or even entire scenes.\n3. **Music Generators**: These models can generate music based on a style, genre, or mood. They can be used to create original compositions or even entire albums.\n4. **Video Generators**: These models can generate videos based on a script, scenario, or style. They can be used to create animations, special effects, or even entire movies.\n\nThe benefits of generative AI include:\n\n1. **Increased creativity**: Generative AI models can generate new and original content, which can be used to inspire human creativity or even replace human creativity in certain tasks.\n2. **Improved productivity**: Generative AI models can automate tasks such as data generation, content creation, or even entire workflows.\n3. **Enhanced personalization**: Generative AI models can create customized content based on individual preferences, interests, or needs.\n\nHowever, generative AI also raises several concerns, including:\n\n1. **Bias and fairness**: Generative AI models can perpetuate biases and stereotypes present in the training data.\n2. **Authenticity and ownership**: Generative AI models can generate content that is difficult to distinguish from human-created content, raising questions about ownership and authenticity.\n3. **Job displacement**: Generative AI models can automate tasks and jobs, potentially displacing human workers.\n\nExamples of generative AI include:\n\n1. **Chatbots**: Chatbots use generative AI to generate human-like responses to user queries.\n2. **Virtual assistants**: Virtual assistants, such as Siri or Alexa, use generative AI to generate responses to user queries.\n3. **Art generators**: Art generators, such as Deep Dream or Prisma, use generative AI to generate original artwork.\n4. **Music generators**: Music generators, such as Amper Music or AIVA, use generative AI to generate original music.\n\nOverall, generative AI has the potential to revolutionize various industries and aspects of life, but it also requires careful consideration of its potential risks and consequences.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 597, 'prompt_tokens': 40, 'total_tokens': 637, 'completion_time': 0.787889853, 'completion_tokens_details': None, 'prompt_time': 0.001901249, 'prompt_tokens_details': None, 'queue_time': 0.15871468, 'total_time': 0.789791102}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e1a0d-6f40-7900-9165-5c687cdd4142-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 597, 'total_tokens': 637})

# %%
## ChatPrompt template

from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# Chain
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about langsmith?"})
print(response)
# Out:
# content='Langsmith is an open-source, cloud-based language platform that aims to provide a comprehensive suite of tools for natural language processing (NLP) tasks. It was developed by Langsmith, Inc., a company founded by a team of experienced AI engineers and researchers.\n\nSome of the key features of Langsmith include:\n\n1. **Text Generation**: Langsmith offers a range of text generation capabilities, including language translation, text summarization, sentiment analysis, and more.\n2. **Conversational AI**: The platform provides tools for building conversational interfaces, such as chatbots and voice assistants, using NLP and machine learning techniques.\n3. **Sentiment Analysis**: Langsmith offers advanced sentiment analysis capabilities, allowing users to analyze text data and determine the overall sentiment or emotional tone.\n4. **Named Entity Recognition (NER)**: The platform provides NER capabilities, allowing users to identify and extract specific entities such as names, locations, organizations, and more.\n5. **Text Classification**: Langsmith offers text classification capabilities, allowing users to categorize text data into predefined categories or classes.\n\nLangsmith is built on top of a cloud-based infrastructure, making it scalable and accessible from anywhere. The platform is designed to be user-friendly, with a simple and intuitive interface that allows users to quickly get started with NLP tasks.\n\nSome of the benefits of using Langsmith include:\n\n1. **Easy to use**: Langsmith provides a user-friendly interface that makes it easy to get started with NLP tasks, even for those without extensive technical expertise.\n2. **Scalable**: The platform is built on top of a cloud-based infrastructure, making it scalable and accessible from anywhere.\n3. **Cost-effective**: Langsmith offers a pay-as-you-go pricing model, making it a cost-effective solution for businesses and organizations.\n4. **Customizable**: The platform allows users to customize their NLP models and workflows to meet their specific needs and requirements.\n\nOverall, Langsmith is a powerful and flexible language platform that provides a range of NLP capabilities and tools for businesses and organizations looking to leverage the power of AI and machine learning.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 427, 'prompt_tokens': 57, 'total_tokens': 484, 'completion_time': 0.528917119, 'completion_tokens_details': None, 'prompt_time': 0.003563395, 'prompt_tokens_details': None, 'queue_time': 0.059575841, 'total_time': 0.532480514}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e1a0d-87f2-7c52-a1f4-dd48c1ee24f5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 57, 'output_tokens': 427, 'total_tokens': 484}

# %%
## stroutput parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about langsmith?"})
print(response)
# Out:
# Langsmith is a popular open-source, AI-powered language generation platform developed by LangChain. It's primarily used for tasks such as language translation, text summarization, and conversational dialogue.
#
# Langsmith is built on top of the LangChain framework, which provides a flexible and scalable architecture for building large language models (LLMs). The platform allows developers to leverage the power of LLMs for various applications, including but not limited to:
#
# 1. **Language Translation**: Langsmith can be used to translate text from one language to another, with support for multiple languages and dialects.
# 2. **Text Summarization**: The platform can summarize long pieces of text into concise, relevant summaries.
# 3. **Conversational Dialogue**: Langsmith enables developers to create conversational interfaces, such as chatbots and virtual assistants.
# 4. **Content Generation**: The platform can generate high-quality content, such as articles, product descriptions, and social media posts.
#
# Langsmith is built on the principles of modular architecture, which allows developers to easily integrate and combine different language models and tools to create custom solutions. This modular approach also enables developers to reuse and modify existing models, making it easier to adapt to changing requirements.
#
# Langsmith's key features include:
#
# 1. **Easy Integration**: The platform provides simple APIs and SDKs for integrating with popular frameworks and libraries, such as Python, JavaScript, and Java.
# 2. **Model Customization**: Developers can customize the language models used by Langsmith to suit their specific needs.
# 3. **Scalability**: The platform is designed to scale horizontally, making it suitable for large-scale deployments.
# 4. **Security**: Langsmith provides robust security features, such as data encryption and access control, to ensure the confidentiality and integrity of user data.
#
# Overall, Langsmith is a powerful language generation platform that enables developers to create innovative applications that leverage the power of LLMs. Its modular architecture and easy integration make it an ideal choice for developers looking to build custom language-based solutions.
